# %%
bronze = spark.read.format("delta").load(bronze_path)

bronze.groupBy("source_system").count().show()
# Out:
# +-------------+-----+
# |source_system|count|
# +-------------+-----+
# |    MARKETING| 2341|
# |      BANKING|10639|
# |          ERP|  527|
# |          CRM|  528|
# +-------------+-----+
